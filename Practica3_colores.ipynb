# %%
color=input("Ingrese el color del semáforo:")
if color == "verde":
    print("AVANZAR")
elif color == "amarillo":
  print("PRECAUCIÓN")
elif color == "rojo":
  print("ALTO")
else:
  print("Color no reconocido")
# Out:
# Ingrese el color del semáforo:verde
# AVANZAR
